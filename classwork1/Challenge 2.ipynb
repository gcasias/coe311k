# %%
n = 2025
binary = ""

while n > 0:
    remainder = n % 2
    print (n,"/2=", n // 2, "with remainder", remainder)
    binary = str(remainder) + binary
    n=n//2
    
print("Binary:",binary)
# Out:
# 2025 /2= 1012 with remainder 1
# 1012 /2= 506 with remainder 0
# 506 /2= 253 with remainder 0
# 253 /2= 126 with remainder 1
# 126 /2= 63 with remainder 0
# 63 /2= 31 with remainder 1
# 31 /2= 15 with remainder 1
# 15 /2= 7 with remainder 1
# 7 /2= 3 with remainder 1
# 3 /2= 1 with remainder 1
# 1 /2= 0 with remainder 1
# Binary: 11111101001

# %% [markdown]
# Asked Copilot how to use modulo to get a remainder and how the modulo function works, I always find myself confused with this topic.
