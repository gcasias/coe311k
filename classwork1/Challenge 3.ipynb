# %%
import random
import numpy

def montecarlo_pi(number_of_shots):
    number_of_hits = 0
    for i in range(0,number_of_shots):
        x = random.uniform(-1,1)
        y = random.uniform(-1,1)
        
        if (x*x + y*y <1):
            number_of_hits = number_of_hits + 1
        
    return 4*number_of_hits/number_of_shots

# %%
import math
import matplotlib.pyplot as plt

for i in range (0,100):
    calculated_pi = montecarlo_pi(1000)
    true_pi = numpy.pi
    true_error = abs(true_pi - calculated_pi)
    relative_error = abs((true_pi - calculated_pi)/true_pi)
    
print(i,calculated_pi,true_error,relative_error)

plt.plot(absolute_errors)
plt.plot(relative_errors)
# Out:
# 99 3.048 0.09359265358979307 0.02979146691180598
