# %%
import numpy as np
import matplyplot.plt as plt
import math 

h = 0.02
x _start, x_end = 0,2
num_steps = int((x_end - x_start) / h)
x_values = np.linspace(x_start, x_end, num_steps + 1)
y_values = np.zeros(num_steps + 1)

y_values[0] = 0

def(x,y):
    return -100*y + 3000 - 2000*math.exp(-x)

plt.legend()
plt.show()
