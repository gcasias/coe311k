# %%
# From Lecture Slides
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import CubicSpline

# Define known data points
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([0, 1, 0, 1, 0, 1])

# Create a cubic spline interpolation of the data
cs = CubicSpline(x, y, bc_type='natural')

# Generate new x values for a smooth plot
x_interp = np.linspace(0, 5, 100)
y_interp = cs(x_interp)

# Pulled from Challenge 10
degree = 5
coefficients = np.polyfit(x,y,degree)
polynomial = np.poly1d(coefficients) 
y_poly = polynomial(x_interp) 

# When asking Chat GPT to look over my code it recommened using x_interp instead of x for the polynomial fit
plt.plot(x, y, 'bo', label="Data Points")
plt.plot(x_interp, y_interp, 'r-', label="Cubic Spline")
plt.plot(x_interp, y_poly, 'g--', label="Polynomial Fit")

plt.title("Cubic Spline vs Polynomial Fit")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()
