# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the parameters
k = 1.0     # Constant in the equation (e.g., spring constant)
h_values = [0.01,0.02,0.03,0.05,0.1,0.2,0.3,0.5]   # Step size
x_start = 0  # Start of the interval
x_end = 10  # End of the interval
y_0 = 1.0   # Initial condition for y
v_0 = 0.0   # Initial condition for dy/dx

plt.figure(figsize=(10, 5))

for h in h_values:
    x_values = np.arange(x_start, x_end + h, h)
    y_values = np.zeros(len(x_values))
    v_values = np.zeros(len(x_values))

    # Set initial conditions
    y_values[0] = y_0
    v_values[0] = v_0

    # Euler's Method loop
    for i in range(1, len(x_values)):
        # Current values
        x_n = x_values[i - 1]
        y_n = y_values[i - 1]
        v_n = v_values[i - 1]  
    
        # Update equations
        y_values[i] = y_n + h * v_n
        v_values[i] = v_n + h * (-k * y_n)
        
    plt.plot(x_values, y_values, label=f'h={h}') 

# Plot the results
plt.xlabel('x')
plt.ylabel('y')
plt.title('Solution with Different Step Sizes')
plt.legend()
plt.grid(True)
plt.show()

# Ran through ChatGPT to ensure no errors and met challenge requirements

# %% [markdown]
# ## When does it become unstable?
# It becomes unstable around h = 0.2-0.3.
#
# ## Is it becoming unstable?
# Yes, it is becoming unstable.
#
# ## Play with the value of K, what are you seeing? Set k = 10, h = .01.Thoughts on whether Euler's Method can solve this with a larger h?
# As h increases, the graph becomes more unstable and less acurate.
