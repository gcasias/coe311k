# %%
import numpy as np

def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
            
# Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations

# %%
import numpy as np
def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = x.copy()
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
            x_new[i] = (b[i] - s1 - s2) / A[i][i]

# Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations

# %%
A = np.array([[10,-1,2,0,0],
            [-1,11,-1,3,0],
            [2,-1,10,-1,0],
            [0,3,-1,8,-2],
            [0,0,0,-2,9]])

b = np.array([14,30,26,25,37])

x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100

solution, iterations = jacobi(A, b, x0, tol, max_iterations)
print("Matrix 1 - Jacobi")
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")

#Asked ChatGPT how to find time for this to run as stated in assignment
import time

start = time.time()
solution, iterations = jacobi(A, b, x0, tol, max_iterations)
end = time.time()
print("Time:", end - start)

solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)
print("\nMatrix 1 - Gauss-Seidel")
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")

import time

start = time.time()
solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)
end = time.time()
print("Time:", end - start)
# Out:
# Matrix 1 - Jacobi
# Solution: [1 2 2 3 4]
# Iterations: 1
# Time: 0.0002627372741699219
#
# Matrix 1 - Gauss-Seidel
# Solution: [1 2 2 3 4]
# Iterations: 2
# Time: 0.00036334991455078125

# %%
A = np.array([[1,2,3,0,0],
            [2,1,2,3,0],
            [3,2,1,2,3],
            [0,3,2,1,2],
            [0,0,3,2,1]])

b = np.array([14,22,33,26,22])

x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100

solution, iterations = jacobi(A, b, x0, tol, max_iterations)
print("Matrix 1 - Jacobi")
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")

import time

start = time.time()
solution, iterations = jacobi(A, b, x0, tol, max_iterations)
end = time.time()
print("Time:", end - start)

solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)
print("\nMatrix 1 - Gauss-Seidel")
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")

import time

start = time.time()
solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)
end = time.time()
print("Time:", end - start)
# Out:
# Matrix 1 - Jacobi
# Solution: [-5976176488926883840 -4324294422220818432   125198747742650400
#  -4324294422220818432 -5976176488926883840]
# Iterations: 100
# Time: 0.007393598556518555
#
# Matrix 1 - Gauss-Seidel
# Solution: [-4667072227903264768 -5861557759596381184  5941495520527654912
#     32542205762157592   557173100602271744]
# Iterations: 100
# Time: 0.006201982498168945
# <ipython-input-1-fc39b8caaa2b>:9: RuntimeWarning: overflow encountered in long_scalars
#   s = sum(A[i][j] * x[j] for j in range(n) if j != i)
# <ipython-input-2-313b308788a5>:8: RuntimeWarning: overflow encountered in long_scalars
#   s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
# <ipython-input-2-313b308788a5>:10: RuntimeWarning: overflow encountered in long_scalars
#   x_new[i] = (b[i] - s1 - s2) / A[i][i]
